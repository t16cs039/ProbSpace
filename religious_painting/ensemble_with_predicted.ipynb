# %% [markdown]
# # Loading packages

# %%
import numpy as np
import pandas as pd
from google.colab import files

# %% [markdown]
# # Ensemble
#
# |note|accuracy|
# |:--:|:--:|
# |vit+mlp_mixer|0.531|
# |efficientnet+vit+mlp_mixer|0.547|

# %%
efficientnetb0_predicted = np.load('/content/drive/MyDrive/ProbSpace/宗教画テーマの分類/dataset/predicted/efficientnetb0.npy')
vit_predicted = np.load('/content/drive/MyDrive/ProbSpace/宗教画テーマの分類/dataset/predicted/vit.npy')
mpl_mixer_predicted = np.load('/content/drive/MyDrive/ProbSpace/宗教画テーマの分類/dataset/predicted/mlp-mixer.npy')

predicted = efficientnetb0_predicted+vit_predicted+mpl_mixer_predicted

df = pd.concat([pd.DataFrame(np.arange(1, 498), columns=['id']), pd.DataFrame(np.argmax(predicted, axis=1), columns=['y'])], axis=1)

df.to_csv('submission.csv', index=False)

df.head()
# Out:
#    id   y
# 0   1   5
# 1   2  12
# 2   3   2
# 3   4   0
# 4   5   5

# %% [markdown]
# # Downloading csv file automatically

# %%
files.download('submission.csv')

# %% [markdown]
# # End
